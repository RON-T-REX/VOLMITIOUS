# %%
# !pip install yfinance

# %%
import yfinance as yf

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dfs = pd.read_excel("List of Stocks.xlsx")

# %%
dfs.head()
# Out:
#                   Stock Name      SYMBOL
# 0                ACC LIMITED         ACC
# 1       ADANI PORT & SEZ LTD  ADANIPORTS
# 2  ADANI ENTERPRISES LIMITED    ADANIENT
# 3            ADANI POWER LTD  ADANIPOWER
# 4         AMBUJA CEMENTS LTD   AMBUJACEM

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Stock Name  161 non-null    object
#  1   SYMBOL      161 non-null    object
# dtypes: object(2)
# memory usage: 2.6+ KB

# %%
dfs.to_csv('stock.csv', index=False)

# %%
df = pd.read_csv('stock.csv')

# %%
df.head()
# Out:
#                   Stock Name      SYMBOL
# 0                ACC LIMITED         ACC
# 1       ADANI PORT & SEZ LTD  ADANIPORTS
# 2  ADANI ENTERPRISES LIMITED    ADANIENT
# 3            ADANI POWER LTD  ADANIPOWER
# 4         AMBUJA CEMENTS LTD   AMBUJACEM

# %%
df['SYMBOL']
# Out:
# 0             ACC
# 1      ADANIPORTS
# 2        ADANIENT
# 3      ADANIPOWER
# 4       AMBUJACEM
#           ...
# 156           PVR
# 157      TATACHEM
# 158    TATAMOTORS
# 159    TATAMTRDVR
# 160         SUNTV
# Name: SYMBOL, Length: 161, dtype: object

# %%
sym = df['SYMBOL'].values
print(sym)
# Out:
# ['ACC' 'ADANIPORTS' 'ADANIENT' 'ADANIPOWER' 'AMBUJACEM' 'APOLLOHOSP'
#  'ARVIND' 'ASIANPAINT' 'AUROPHARMA' 'BAJFINANCE' 'BALKRISIND' 'BANKBARODA'
#  'BANKINDIA' 'BERGEPAINT' 'BHEL' 'BAJAJFINSV' 'BOSCHLTD' 'CADILAHC'
#  'CENTURYTEX' 'CHOLAFIN' 'CUMMINSIND' 'DIVISLAB' 'DLF' 'ENGINERSIN'
#  'EQUITAS' 'ESCORTS' 'FEDERALBNK' 'GODREJCP' 'GRASIM' 'HAVELLS' 'HCLTECH'
#  'BSOFT' 'HDFCBANK' 'HEXAWARE' 'HINDPETRO' 'CANBK' 'HINDZINC' 'IDEA'
#  'IDFCFIRSTB' 'CASTROLIND' 'INDIGO' 'INDUSINDBK' 'INFY' 'IOC' 'DHFL' 'ITC'
#  'JINDALSTEL' 'EICHERMOT' 'JSWSTEEL' 'JUBLFOOD' 'JUSTDIAL' 'KOTAKBANK'
#  'EXIDEIND' 'L&TFH' 'LUPIN' 'M&M' 'GLENMARK' 'MARICO' 'MCDOWELL-N' 'MCX'
#  'MOTHERSUMI' 'MRF' 'MUTHOOTFIN' 'NATIONALUM' 'NCC' 'ICICIPRULI'
#  'NESTLEIND' 'NTPC' 'ONGC' 'PAGEIND' 'INFRATEL' 'PFC' 'PIDILITIND' 'PNB'
#  'RAMCOCEM' 'RAYMOND' 'RECLTD' 'RELCAPITAL' 'RELIANCE' 'SAIL' 'SIEMENS'
#  'SRF' 'SRTRANSFIN' 'STAR' 'TATAGLOBAL' 'TATAPOWER' 'TCS' 'MGL' 'TECHM'
# ...

# %%
ticks = df['SYMBOL'].tolist()
ticks
# show the list
#print(symbols)
# Out:
# ['ACC',
#  'ADANIPORTS',
#  'ADANIENT',
#  'ADANIPOWER',
#  'AMBUJACEM',
#  'APOLLOHOSP',
#  'ARVIND',
#  'ASIANPAINT',
#  'AUROPHARMA',
#  'BAJFINANCE',
#  'BALKRISIND',
#  'BANKBARODA',
#  'BANKINDIA',
#  'BERGEPAINT',
#  'BHEL',
#  'BAJAJFINSV',
#  'BOSCHLTD',
#  'CADILAHC',
#  'CENTURYTEX',
#  'CHOLAFIN',
#  'CUMMINSIND',
#  'DIVISLAB',
#  'DLF',
#  'ENGINERSIN',
#  'EQUITAS',
#  'ESCORTS',
#  'FEDERALBNK',
#  'GODREJCP',
#  'GRASIM',
#  'HAVELLS',
#  'HCLTECH',
#  'BSOFT',
#  'HDFCBANK',
#  'HEXAWARE',
#  'HINDPETRO',
#  'CANBK',
#  'HINDZINC',
#  'IDEA',
#  'IDFCFIRSTB',
#  'CASTROLIND',
#  'INDIGO',
#  'INDUSINDBK',
#  'INFY',
#  'IOC',
#  'DHFL',
#  'ITC',
#  'JINDALSTEL',
#  'EICHERMOT',
#  'JSWSTEEL',
#  'JUBLFOOD',
#  'JUSTDIAL',
#  'KOTAKBANK',
#  'EXIDEIND',
#  'L&TFH',
#  'LUPIN',
#  'M&M',
#  'GLENMARK',
#  'MARICO',
#  'MCDOWELL-N',
#  'MCX',
#  'MOTHERSUMI',
#  'MRF',
#  'MUTHOOTFIN',
#  'NATIONALUM',
#  'NCC',
#  'ICICIPRULI',
#  'NESTLEIND',
#  'NTPC',
#  'ONGC',
# ...

# %%
import datetime
end = datetime.date.today()
end = datetime.datetime.strptime(str(end), "%Y-%m-%d") #string to date
start = end - datetime.timedelta(days=90) # date - days
print(start,end)
# Out:
# 2021-07-15 00:00:00 2021-10-13 00:00:00

# %%
append_str = '.NS'
tick = [sub + append_str for sub in ticks]
print("list after suffix addition : " + str(tick))
# Out:
# list after suffix addition : ['ACC.NS', 'ADANIPORTS.NS', 'ADANIENT.NS', 'ADANIPOWER.NS', 'AMBUJACEM.NS', 'APOLLOHOSP.NS', 'ARVIND.NS', 'ASIANPAINT.NS', 'AUROPHARMA.NS', 'BAJFINANCE.NS', 'BALKRISIND.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BERGEPAINT.NS', 'BHEL.NS', 'BAJAJFINSV.NS', 'BOSCHLTD.NS', 'CADILAHC.NS', 'CENTURYTEX.NS', 'CHOLAFIN.NS', 'CUMMINSIND.NS', 'DIVISLAB.NS', 'DLF.NS', 'ENGINERSIN.NS', 'EQUITAS.NS', 'ESCORTS.NS', 'FEDERALBNK.NS', 'GODREJCP.NS', 'GRASIM.NS', 'HAVELLS.NS', 'HCLTECH.NS', 'BSOFT.NS', 'HDFCBANK.NS', 'HEXAWARE.NS', 'HINDPETRO.NS', 'CANBK.NS', 'HINDZINC.NS', 'IDEA.NS', 'IDFCFIRSTB.NS', 'CASTROLIND.NS', 'INDIGO.NS', 'INDUSINDBK.NS', 'INFY.NS', 'IOC.NS', 'DHFL.NS', 'ITC.NS', 'JINDALSTEL.NS', 'EICHERMOT.NS', 'JSWSTEEL.NS', 'JUBLFOOD.NS', 'JUSTDIAL.NS', 'KOTAKBANK.NS', 'EXIDEIND.NS', 'L&TFH.NS', 'LUPIN.NS', 'M&M.NS', 'GLENMARK.NS', 'MARICO.NS', 'MCDOWELL-N.NS', 'MCX.NS', 'MOTHERSUMI.NS', 'MRF.NS', 'MUTHOOTFIN.NS', 'NATIONALUM.NS', 'NCC.NS', 'ICICIPRULI.NS', 'NESTLE
# ...

# %%
yf.download(tick , start = '2021-07-16' , end = '2021-10-12' , group_by = 'ticker')
# Out:
# [*********************100%***********************]  161 of 161 completed
#
# 4 Failed downloads:
# - INFRATEL.NS: No data found, symbol may be delisted
# - NIITTECH.NS: No data found, symbol may be delisted
# - TATAGLOBAL.NS: No data found, symbol may be delisted
# - HEXAWARE.NS: No data found for this date range, symbol may be delisted
#                NTPC.NS                                                  \
#                   Open        High         Low       Close   Adj Close
# Date
# 2021-07-16  120.150002  120.800003  118.300003  119.099998  112.912430
# 2021-07-19  119.099998  121.849998  118.500000  121.400002  115.092941
# 2021-07-20  122.000000  122.000000  118.199997  118.449997  112.296196
# 2021-07-22  118.750000  119.699997  118.550003  119.199997  113.007233
# 2021-07-23  119.400002  120.099998  118.300003  118.500000  112.343605
# 2021-07-26  118.199997  120.000000  118.050003  119.349998  113.149445
# ...

# %% [markdown]
# 4 Failed downloads:
# - NIITTECH: No data found, symbol may be delisted
# - INFRATEL: No data found, symbol may be delisted
# - TATAGLOBAL: No data found, symbol may be delisted
# - HEXAWARE: No data found for this date range, symbol may be delisted
# - To fetch data of Indian stocks from Yahoo! Finance, you need to add .NS after the Stock Ticker. Did for above with and without .NS , yahoo finance sometimes dont reveal much info of few stocks seen on stack ,reddit

# %%
#tata = yf.download("HEXAWARE", start = '2021-07-16' , end = '2021-10-12' , rounding = True)['Close']

# %%
#tata

# %% [markdown]
# - Using rounding = True to get roundoff value
# - And getting only closing data

# %%
yfs= yf.download(tick , start = '2021-07-16' , end = '2021-10-12' , rounding = True)['Close']
# Out:
# [*********************100%***********************]  161 of 161 completed
#
# 4 Failed downloads:
# - INFRATEL.NS: No data found, symbol may be delisted
# - NIITTECH.NS: No data found, symbol may be delisted
# - TATAGLOBAL.NS: No data found, symbol may be delisted
# - HEXAWARE.NS: No data found for this date range, symbol may be delisted

# %%
yfs
# Out:
#              ACC.NS  ADANIENT.NS  ADANIPORTS.NS  ADANIPOWER.NS  AMARAJABAT.NS  \
# Date
# 2021-07-16  2129.35      1395.50         687.60         105.65         727.85
# 2021-07-19  2151.90      1380.60         673.70         102.15         722.30
# 2021-07-20  2308.85      1365.70         672.60          97.05         713.35
# 2021-07-22  2290.25      1416.75         691.80         101.80         721.80
# 2021-07-23  2337.55      1401.65         680.05         100.45         723.25
# 2021-07-26  2369.20      1403.90         682.80          97.95         724.20
# 2021-07-27  2371.70      1396.75         663.20          94.75         718.30
# 2021-07-28  2393.90      1399.90         665.40          97.05         713.40
# 2021-07-29  2364.00      1400.25         659.65          95.40         694.85
# 2021-07-30  2394.10      1420.25         674.50          95.85         719.85
# 2021-08-02  2424.00      1438.20         692.00          92.85         720.45
# ...

# %%
yfs.columns
# Out:
# Index(['ACC.NS', 'ADANIENT.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS',
#        'AMARAJABAT.NS', 'AMBUJACEM.NS', 'APOLLOHOSP.NS', 'APOLLOTYRE.NS',
#        'ARVIND.NS', 'ASHOKLEY.NS',
#        ...
#        'UBL.NS', 'UJJIVAN.NS', 'ULTRACEMCO.NS', 'UNIONBANK.NS', 'UPL.NS',
#        'VEDL.NS', 'VOLTAS.NS', 'WIPRO.NS', 'YESBANK.NS', 'ZEEL.NS'],
#       dtype='object', length=161)

# %%
#removing .NS suffix from columns
yfs.columns = yfs.columns.str.replace(r'.NS$', '')

yfs.columns
# Out:
# <ipython-input-18-8303c2fef120>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   yfs.columns = yfs.columns.str.replace(r'.NS$', '')
# Index(['ACC', 'ADANIENT', 'ADANIPORTS', 'ADANIPOWER', 'AMARAJABAT',
#        'AMBUJACEM', 'APOLLOHOSP', 'APOLLOTYRE', 'ARVIND', 'ASHOKLEY',
#        ...
#        'UBL', 'UJJIVAN', 'ULTRACEMCO', 'UNIONBANK', 'UPL', 'VEDL', 'VOLTAS',
#        'WIPRO', 'YESBANK', 'ZEEL'],
#       dtype='object', length=161)

# %%
yfs.head()
# Out:
#                 ACC  ADANIENT  ADANIPORTS  ADANIPOWER  AMARAJABAT  AMBUJACEM  \
# Date
# 2021-07-16  2129.35   1395.50      687.60      105.65      727.85     383.05
# 2021-07-19  2151.90   1380.60      673.70      102.15      722.30     386.55
# 2021-07-20  2308.85   1365.70      672.60       97.05      713.35     404.45
# 2021-07-22  2290.25   1416.75      691.80      101.80      721.80     400.20
# 2021-07-23  2337.55   1401.65      680.05      100.45      723.25     402.30
#
#             APOLLOHOSP  APOLLOTYRE  ARVIND  ASHOKLEY  ...      UBL  UJJIVAN  \
# Date                                                  ...
# 2021-07-16     3779.10      230.85  108.15    127.85  ...  1447.90   242.10
# 2021-07-19     3883.75      225.35  105.05    124.75  ...  1419.30   236.45
# 2021-07-20     3882.95      221.70  102.20    123.35  ...  1411.60   234.55
# 2021-07-22     3985.30      226.45  108.60    124.05  ...  1429.80   235.85
# ...

# %%
yfs.tail()
# Out:
#                 ACC  ADANIENT  ADANIPORTS  ADANIPOWER  AMARAJABAT  AMBUJACEM  \
# Date
# 2021-10-05  2263.70   1527.65      743.95      106.50      765.50     403.65
# 2021-10-06  2203.25   1479.55      724.00      101.55      749.70     394.90
# 2021-10-07  2265.85   1520.75      736.15      101.95      758.70     402.90
# 2021-10-08  2240.90   1547.90      739.90      101.60      760.00     403.05
# 2021-10-11  2249.85   1539.75      737.45      101.85      770.55     402.95
#
#             APOLLOHOSP  APOLLOTYRE  ARVIND  ASHOKLEY  ...      UBL  UJJIVAN  \
# Date                                                  ...
# 2021-10-05     4482.40      225.25  108.70    132.25  ...  1613.35   153.60
# 2021-10-06     4378.75      222.30  103.70    129.85  ...  1589.15   151.80
# 2021-10-07     4428.30      228.15  104.20    135.85  ...  1643.70   152.30
# 2021-10-08     4379.25      234.50  102.65    134.90  ...  1650.05   153.10
# ...

# %%
yfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 59 entries, 2021-07-16 to 2021-10-11
# Columns: 161 entries, ACC to ZEEL
# dtypes: float64(161)
# memory usage: 74.7 KB

# %%
yfs.describe()
# Out:
#                ACC     ADANIENT  ADANIPORTS  ADANIPOWER  AMARAJABAT  \
# count    59.000000    59.000000   59.000000   59.000000   59.000000
# mean   2340.113559  1474.082203  719.892373   94.474576  724.950847
# std      82.744596    57.826911   30.947298    8.062768   23.026753
# min    2129.350000  1365.700000  659.650000   73.600000  666.300000
# 25%    2278.500000  1431.225000  693.275000   90.300000  717.925000
# 50%    2332.300000  1468.100000  727.000000   96.950000  722.300000
# 75%    2396.725000  1523.700000  745.400000  100.450000  736.050000
# max    2483.500000  1587.600000  769.650000  108.550000  770.550000
#
#         AMBUJACEM   APOLLOHOSP  APOLLOTYRE      ARVIND    ASHOKLEY  ...  \
# count   59.000000    59.000000   59.000000   59.000000   59.000000  ...
# mean   411.263559  4486.844915  221.967797   98.211017  127.100847  ...
# std     14.167276   384.409891    7.227908    5.907105    5.515218  ...
# ...

# %%
yfs.reset_index(level='Date', inplace=True)

# %%
yfs.head()
# Out:
#         Date      ACC  ADANIENT  ADANIPORTS  ADANIPOWER  AMARAJABAT  \
# 0 2021-07-16  2129.35   1395.50      687.60      105.65      727.85
# 1 2021-07-19  2151.90   1380.60      673.70      102.15      722.30
# 2 2021-07-20  2308.85   1365.70      672.60       97.05      713.35
# 3 2021-07-22  2290.25   1416.75      691.80      101.80      721.80
# 4 2021-07-23  2337.55   1401.65      680.05      100.45      723.25
#
#    AMBUJACEM  APOLLOHOSP  APOLLOTYRE  ARVIND  ...      UBL  UJJIVAN  \
# 0     383.05     3779.10      230.85  108.15  ...  1447.90   242.10
# 1     386.55     3883.75      225.35  105.05  ...  1419.30   236.45
# 2     404.45     3882.95      221.70  102.20  ...  1411.60   234.55
# 3     400.20     3985.30      226.45  108.60  ...  1429.80   235.85
# 4     402.30     3918.90      226.80  104.85  ...  1444.45   237.10
#
#    ULTRACEMCO  UNIONBANK     UPL   VEDL   VOLTAS   WIPRO  YESBANK    ZEEL
# ...

# %%
yfs.to_csv('stocks90.csv', index=False)

# %%
yfs.to_excel('stocks90.xlsx', index=False)
